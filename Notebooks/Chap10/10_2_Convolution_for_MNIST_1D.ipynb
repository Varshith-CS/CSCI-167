# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshith-CS/CSCI-167/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-mn3nrk2u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-mn3nrk2u
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.754189, train error 69.90,  val loss 1.751289, percent error 71.20
# Epoch     1, train loss 1.418584, train error 57.42,  val loss 1.467134, percent error 60.70
# Epoch     2, train loss 1.368352, train error 55.58,  val loss 1.384995, percent error 57.70
# Epoch     3, train loss 1.264435, train error 51.88,  val loss 1.284304, percent error 53.30
# Epoch     4, train loss 1.159389, train error 47.38,  val loss 1.198342, percent error 50.10
# Epoch     5, train loss 1.024445, train error 41.10,  val loss 1.050647, percent error 44.10
# Epoch     6, train loss 0.931669, train error 38.47,  val loss 0.959353, percent error 38.80
# Epoch     7, train loss 0.877495, train error 35.68,  val loss 0.900876, percent error 38.20
# Epoch     8, train loss 0.803428, train error 33.00,  val loss 0.859475, percent error 34.60
# Epoch     9, train loss 0.668869, train error 26.60,  val loss 0.731288, percent error 29.80
# Epoch    10, train loss 0.724009, train error 30.35,  val loss 0.792228, percent error 33.60
# Epoch    11, train loss 0.606747, train error 24.05,  val loss 0.688742, percent error 26.60
# Epoch    12, train loss 0.527316, train error 20.43,  val loss 0.614675, percent error 25.60
# Epoch    13, train loss 0.533091, train error 20.25,  val loss 0.649519, percent error 25.50
# Epoch    14, train loss 0.443819, train error 16.75,  val loss 0.552599, percent error 22.30
# Epoch    15, train loss 0.460922, train error 18.22,  val loss 0.556367, percent error 21.50
# Epoch    16, train loss 0.400957, train error 14.45,  val loss 0.544984, percent error 20.80
# Epoch    17, train loss 0.349827, train error 13.32,  val loss 0.497083, percent error 19.30
# Epoch    18, train loss 0.383614, train error 14.22,  val loss 0.528530, percent error 19.00
# Epoch    19, train loss 0.298476, train error 10.82,  val loss 0.467074, percent error 17.90
# Epoch    20, train loss 0.235250, train error 8.35,  val loss 0.409385, percent error 15.00
# Epoch    21, train loss 0.202116, train error 6.75,  val loss 0.383282, percent error 13.50
# Epoch    22, train loss 0.208113, train error 7.32,  val loss 0.383727, percent error 14.00
# Epoch    23, train loss 0.191056, train error 6.53,  val loss 0.390364, percent error 13.30
# Epoch    24, train loss 0.207025, train error 7.70,  val loss 0.390970, percent error 12.80
# Epoch    25, train loss 0.172680, train error 5.93,  val loss 0.379239, percent error 12.90
# Epoch    26, train loss 0.156671, train error 5.18,  val loss 0.376632, percent error 13.30
# Epoch    27, train loss 0.168315, train error 5.82,  val loss 0.379625, percent error 13.10
# Epoch    28, train loss 0.150423, train error 4.65,  val loss 0.383532, percent error 12.80
# Epoch    29, train loss 0.140018, train error 4.70,  val loss 0.376709, percent error 12.50
# Epoch    30, train loss 0.153979, train error 5.53,  val loss 0.388279, percent error 13.10
# Epoch    31, train loss 0.136510, train error 4.60,  val loss 0.379237, percent error 11.90
# Epoch    32, train loss 0.138984, train error 4.82,  val loss 0.396073, percent error 12.50
# Epoch    33, train loss 0.126552, train error 4.15,  val loss 0.382417, percent error 12.80
# Epoch    34, train loss 0.150727, train error 5.35,  val loss 0.433152, percent error 12.80
# Epoch    35, train loss 0.123715, train error 4.35,  val loss 0.364044, percent error 11.20
# Epoch    36, train loss 0.112166, train error 3.82,  val loss 0.390234, percent error 11.40
# Epoch    37, train loss 0.132929, train error 4.78,  val loss 0.370647, percent error 11.40
# Epoch    38, train loss 0.102312, train error 3.28,  val loss 0.375708, percent error 11.60
# Epoch    39, train loss 0.092207, train error 2.93,  val loss 0.351833, percent error 10.30
# Epoch    40, train loss 0.082638, train error 2.53,  val loss 0.364792, percent error 10.80
# Epoch    41, train loss 0.097823, train error 3.38,  val loss 0.391478, percent error 10.10
# Epoch    42, train loss 0.075457, train error 1.90,  val loss 0.372322, percent error 10.90
# Epoch    43, train loss 0.072198, train error 1.90,  val loss 0.359405, percent error 10.70
# Epoch    44, train loss 0.068523, train error 1.72,  val loss 0.353284, percent error 10.90
# Epoch    45, train loss 0.072004, train error 2.12,  val loss 0.356732, percent error 10.60
# Epoch    46, train loss 0.067280, train error 1.68,  val loss 0.356706, percent error 10.10
# Epoch    47, train loss 0.062774, train error 1.65,  val loss 0.372120, percent error 10.90
# Epoch    48, train loss 0.064060, train error 1.62,  val loss 0.364757, percent error 10.50
# Epoch    49, train loss 0.060442, train error 1.47,  val loss 0.372586, percent error 10.10
# Epoch    50, train loss 0.060382, train error 1.47,  val loss 0.373640, percent error 10.20
# Epoch    51, train loss 0.057709, train error 1.45,  val loss 0.372492, percent error 10.50
# Epoch    52, train loss 0.056309, train error 1.28,  val loss 0.365166, percent error 9.90
# Epoch    53, train loss 0.060436, train error 1.62,  val loss 0.386351, percent error 10.00
# Epoch    54, train loss 0.055004, train error 1.18,  val loss 0.383629, percent error 9.90
# Epoch    55, train loss 0.054340, train error 1.45,  val loss 0.379257, percent error 10.50
# Epoch    56, train loss 0.051308, train error 1.05,  val loss 0.393728, percent error 10.30
# Epoch    57, train loss 0.053525, train error 1.32,  val loss 0.409298, percent error 11.10
# Epoch    58, train loss 0.047421, train error 0.90,  val loss 0.390145, percent error 10.20
# Epoch    59, train loss 0.049901, train error 1.32,  val loss 0.381698, percent error 10.50
# Epoch    60, train loss 0.042868, train error 0.75,  val loss 0.372165, percent error 9.80
# Epoch    61, train loss 0.041747, train error 0.70,  val loss 0.380093, percent error 10.00
# Epoch    62, train loss 0.041666, train error 0.72,  val loss 0.386032, percent error 10.10
# Epoch    63, train loss 0.042598, train error 0.82,  val loss 0.389269, percent error 10.10
# Epoch    64, train loss 0.040278, train error 0.70,  val loss 0.380246, percent error 10.10
# Epoch    65, train loss 0.039491, train error 0.65,  val loss 0.392410, percent error 9.90
# Epoch    66, train loss 0.039124, train error 0.62,  val loss 0.395830, percent error 10.10
# Epoch    67, train loss 0.039847, train error 0.68,  val loss 0.386332, percent error 10.20
# Epoch    68, train loss 0.040428, train error 0.72,  val loss 0.403334, percent error 10.30
# Epoch    69, train loss 0.036958, train error 0.62,  val loss 0.392587, percent error 10.20
# Epoch    70, train loss 0.037015, train error 0.47,  val loss 0.387867, percent error 10.40
# Epoch    71, train loss 0.036097, train error 0.53,  val loss 0.390901, percent error 10.30
# Epoch    72, train loss 0.037994, train error 0.65,  val loss 0.404571, percent error 9.80
# Epoch    73, train loss 0.035539, train error 0.40,  val loss 0.396514, percent error 10.20
# Epoch    74, train loss 0.039163, train error 0.72,  val loss 0.413683, percent error 10.00
# Epoch    75, train loss 0.034149, train error 0.40,  val loss 0.397287, percent error 10.20
# Epoch    76, train loss 0.033933, train error 0.47,  val loss 0.401527, percent error 9.90
# Epoch    77, train loss 0.033392, train error 0.50,  val loss 0.397671, percent error 10.40
# Epoch    78, train loss 0.033702, train error 0.45,  val loss 0.401700, percent error 10.10
# Epoch    79, train loss 0.032918, train error 0.30,  val loss 0.398355, percent error 10.40
# Epoch    80, train loss 0.032240, train error 0.40,  val loss 0.406853, percent error 10.10
# Epoch    81, train loss 0.031403, train error 0.38,  val loss 0.399588, percent error 10.10
# Epoch    82, train loss 0.031384, train error 0.30,  val loss 0.400657, percent error 10.00
# Epoch    83, train loss 0.031184, train error 0.45,  val loss 0.407653, percent error 10.00
# Epoch    84, train loss 0.030936, train error 0.38,  val loss 0.404102, percent error 10.10
# Epoch    85, train loss 0.030604, train error 0.43,  val loss 0.405168, percent error 10.00
# Epoch    86, train loss 0.030467, train error 0.35,  val loss 0.404291, percent error 10.10
# Epoch    87, train loss 0.030218, train error 0.32,  val loss 0.407092, percent error 10.00
# Epoch    88, train loss 0.029921, train error 0.25,  val loss 0.405774, percent error 10.30
# Epoch    89, train loss 0.030205, train error 0.35,  val loss 0.401665, percent error 10.20
# Epoch    90, train loss 0.030117, train error 0.32,  val loss 0.400726, percent error 10.00
# Epoch    91, train loss 0.029692, train error 0.22,  val loss 0.402919, percent error 10.30
# Epoch    92, train loss 0.029149, train error 0.25,  val loss 0.405983, percent error 10.30
# Epoch    93, train loss 0.028957, train error 0.28,  val loss 0.409811, percent error 10.30
# Epoch    94, train loss 0.029610, train error 0.22,  val loss 0.405939, percent error 10.50
# Epoch    95, train loss 0.029301, train error 0.20,  val loss 0.404341, percent error 10.20
# Epoch    96, train loss 0.028591, train error 0.25,  val loss 0.411274, percent error 10.10
# Epoch    97, train loss 0.028510, train error 0.32,  val loss 0.414197, percent error 10.20
# Epoch    98, train loss 0.028217, train error 0.18,  val loss 0.410364, percent error 10.30
# Epoch    99, train loss 0.027977, train error 0.22,  val loss 0.416109, percent error 10.30
