# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshith-CS/CSCI-167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-89hfxb2m
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-89hfxb2m
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=be01e9ca4cf883bad3572d8bbea9dad0590d1c910bb54e0090f94c34e81e8193
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ugydqbga/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# Answers:
# 1. 0: around 40–60 hidden units
# 2. First minimum: around 16–24 hidden units
# 3. Maximum (peak): around 40–50 hidden units

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.280271, train error 88.10,  test loss 2.274972, test error 87.88
# Epoch   100, train loss 1.925661, train error 72.28,  test loss 1.762185, test error 70.47
# Epoch   200, train loss 1.918106, train error 71.43,  test loss 1.746729, test error 70.38
# Epoch   300, train loss 1.910891, train error 71.18,  test loss 1.750366, test error 68.80
# Epoch   400, train loss 1.911760, train error 71.93,  test loss 1.732875, test error 70.25
# Epoch   500, train loss 1.906150, train error 71.75,  test loss 1.734766, test error 69.18
# Epoch   600, train loss 1.914679, train error 72.03,  test loss 1.768333, test error 69.05
# Epoch   700, train loss 1.902799, train error 71.53,  test loss 1.736691, test error 69.20
# Epoch   800, train loss 1.904452, train error 71.50,  test loss 1.733465, test error 69.07
# Epoch   900, train loss 1.917187, train error 72.30,  test loss 1.769021, test error 69.82
# Training model with   4 hidden variables
# Epoch     0, train loss 2.282650, train error 86.00,  test loss 2.277642, test error 85.78
# Epoch   100, train loss 1.829956, train error 68.65,  test loss 1.696221, test error 67.62
# Epoch   200, train loss 1.819387, train error 68.65,  test loss 1.688334, test error 68.12
# Epoch   300, train loss 1.811165, train error 68.35,  test loss 1.691228, test error 67.90
# Epoch   400, train loss 1.801127, train error 67.35,  test loss 1.675476, test error 66.80
# Epoch   500, train loss 1.784642, train error 66.85,  test loss 1.640602, test error 65.22
# Epoch   600, train loss 1.750554, train error 64.90,  test loss 1.592216, test error 62.50
# Epoch   700, train loss 1.714456, train error 62.17,  test loss 1.510255, test error 57.78
# Epoch   800, train loss 1.681695, train error 61.67,  test loss 1.488908, test error 56.42
# Epoch   900, train loss 1.676223, train error 61.00,  test loss 1.479707, test error 57.03
# Training model with   6 hidden variables
# Epoch     0, train loss 2.172459, train error 82.35,  test loss 2.141317, test error 80.35
# Epoch   100, train loss 1.731315, train error 63.28,  test loss 1.593143, test error 61.60
# Epoch   200, train loss 1.674664, train error 59.62,  test loss 1.551974, test error 60.33
# Epoch   300, train loss 1.629958, train error 58.58,  test loss 1.484386, test error 56.08
# Epoch   400, train loss 1.617053, train error 56.30,  test loss 1.462953, test error 54.28
# Epoch   500, train loss 1.622596, train error 56.78,  test loss 1.483305, test error 54.95
# Epoch   600, train loss 1.615755, train error 56.60,  test loss 1.472728, test error 53.95
# Epoch   700, train loss 1.604705, train error 56.00,  test loss 1.466061, test error 54.40
# Epoch   800, train loss 1.600252, train error 56.35,  test loss 1.461561, test error 54.67
# Epoch   900, train loss 1.594171, train error 56.17,  test loss 1.461700, test error 54.72
# Training model with   8 hidden variables
# Epoch     0, train loss 2.305605, train error 87.10,  test loss 2.311917, test error 87.25
# Epoch   100, train loss 1.633276, train error 57.95,  test loss 1.488104, test error 56.62
# Epoch   200, train loss 1.510105, train error 51.20,  test loss 1.342029, test error 48.70
# Epoch   300, train loss 1.496349, train error 50.10,  test loss 1.338401, test error 49.05
# Epoch   400, train loss 1.489784, train error 49.72,  test loss 1.343648, test error 48.95
# Epoch   500, train loss 1.484155, train error 50.17,  test loss 1.344402, test error 49.55
# Epoch   600, train loss 1.484726, train error 50.22,  test loss 1.355619, test error 50.08
# Epoch   700, train loss 1.485242, train error 50.38,  test loss 1.348413, test error 49.20
# Epoch   800, train loss 1.479586, train error 49.83,  test loss 1.349801, test error 49.65
# Epoch   900, train loss 1.481216, train error 49.90,  test loss 1.342597, test error 49.65
# Training model with  10 hidden variables
# Epoch     0, train loss 2.293510, train error 86.60,  test loss 2.293597, test error 86.05
# Epoch   100, train loss 1.591673, train error 55.50,  test loss 1.440269, test error 55.45
# Epoch   200, train loss 1.532681, train error 53.75,  test loss 1.416234, test error 53.83
# Epoch   300, train loss 1.508194, train error 53.08,  test loss 1.422299, test error 54.83
# Epoch   400, train loss 1.477337, train error 51.83,  test loss 1.425054, test error 54.42
# Epoch   500, train loss 1.470464, train error 51.47,  test loss 1.437178, test error 54.60
# Epoch   600, train loss 1.467992, train error 50.85,  test loss 1.440408, test error 54.65
# Epoch   700, train loss 1.464284, train error 52.33,  test loss 1.452292, test error 55.20
# Epoch   800, train loss 1.450913, train error 50.72,  test loss 1.450596, test error 54.80
# Epoch   900, train loss 1.456687, train error 50.55,  test loss 1.461908, test error 55.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.218901, train error 83.60,  test loss 2.204334, test error 82.53
# Epoch   100, train loss 1.408830, train error 48.10,  test loss 1.301695, test error 47.95
# Epoch   200, train loss 1.320440, train error 44.97,  test loss 1.266870, test error 45.92
# Epoch   300, train loss 1.295793, train error 43.67,  test loss 1.292788, test error 47.17
# Epoch   400, train loss 1.271350, train error 43.60,  test loss 1.312522, test error 47.20
# Epoch   500, train loss 1.261145, train error 43.45,  test loss 1.326040, test error 47.50
# Epoch   600, train loss 1.255603, train error 42.97,  test loss 1.347295, test error 47.75
# Epoch   700, train loss 1.245973, train error 42.15,  test loss 1.355653, test error 48.15
# Epoch   800, train loss 1.250638, train error 42.58,  test loss 1.385908, test error 49.00
# Epoch   900, train loss 1.244613, train error 41.58,  test loss 1.374047, test error 48.58
# Training model with  18 hidden variables
# Epoch     0, train loss 2.257802, train error 84.35,  test loss 2.248233, test error 83.38
# Epoch   100, train loss 1.370182, train error 47.03,  test loss 1.336619, test error 50.35
# Epoch   200, train loss 1.263471, train error 42.38,  test loss 1.358180, test error 49.80
# Epoch   300, train loss 1.202770, train error 41.03,  test loss 1.410541, test error 50.72
# Epoch   400, train loss 1.180416, train error 39.97,  test loss 1.455722, test error 50.72
# Epoch   500, train loss 1.150101, train error 39.97,  test loss 1.500351, test error 51.38
# Epoch   600, train loss 1.136642, train error 38.97,  test loss 1.524470, test error 51.88
# Epoch   700, train loss 1.129303, train error 38.50,  test loss 1.551310, test error 52.15
# Epoch   800, train loss 1.119646, train error 38.42,  test loss 1.559906, test error 51.97
# Epoch   900, train loss 1.128989, train error 38.88,  test loss 1.614152, test error 52.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.203779, train error 81.43,  test loss 2.164684, test error 80.00
# Epoch   100, train loss 1.254067, train error 41.88,  test loss 1.276639, test error 47.88
# Epoch   200, train loss 1.146814, train error 38.17,  test loss 1.303412, test error 47.60
# Epoch   300, train loss 1.090308, train error 36.83,  test loss 1.396591, test error 49.03
# Epoch   400, train loss 1.057818, train error 36.05,  test loss 1.468537, test error 49.95
# Epoch   500, train loss 1.030902, train error 34.25,  test loss 1.521494, test error 49.67
# Epoch   600, train loss 1.015852, train error 33.65,  test loss 1.539125, test error 49.38
# Epoch   700, train loss 1.003021, train error 33.28,  test loss 1.583196, test error 50.12
# Epoch   800, train loss 0.998011, train error 33.95,  test loss 1.620090, test error 50.58
# Epoch   900, train loss 0.979362, train error 33.43,  test loss 1.629706, test error 50.22
# Training model with  26 hidden variables
# Epoch     0, train loss 2.140765, train error 79.70,  test loss 2.101571, test error 78.80
# Epoch   100, train loss 1.181340, train error 38.58,  test loss 1.330774, test error 49.15
# Epoch   200, train loss 1.021613, train error 33.43,  test loss 1.452833, test error 49.60
# Epoch   300, train loss 0.965788, train error 31.57,  test loss 1.582904, test error 51.58
# Epoch   400, train loss 0.914405, train error 30.28,  test loss 1.691013, test error 52.30
# Epoch   500, train loss 0.876857, train error 29.55,  test loss 1.791767, test error 52.95
# Epoch   600, train loss 0.845198, train error 28.53,  test loss 1.904680, test error 53.67
# Epoch   700, train loss 0.825149, train error 27.93,  test loss 2.018037, test error 53.95
# Epoch   800, train loss 0.813576, train error 27.35,  test loss 2.063719, test error 53.60
# Epoch   900, train loss 0.804527, train error 26.55,  test loss 2.136393, test error 54.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.154588, train error 79.22,  test loss 2.137946, test error 78.97
# Epoch   100, train loss 1.124385, train error 37.60,  test loss 1.376339, test error 51.05
# Epoch   200, train loss 0.910010, train error 29.55,  test loss 1.517648, test error 51.47
# Epoch   300, train loss 0.846332, train error 28.00,  test loss 1.734579, test error 51.55
# Epoch   400, train loss 0.804370, train error 28.40,  test loss 1.884565, test error 52.38
# Epoch   500, train loss 0.746948, train error 26.07,  test loss 2.058001, test error 53.53
# Epoch   600, train loss 0.725993, train error 25.35,  test loss 2.160209, test error 53.20
# Epoch   700, train loss 0.721668, train error 25.53,  test loss 2.302520, test error 53.75
# Epoch   800, train loss 0.697030, train error 24.35,  test loss 2.451890, test error 53.80
# Epoch   900, train loss 0.672223, train error 24.25,  test loss 2.581615, test error 54.67
# Training model with  35 hidden variables
# Epoch     0, train loss 2.124218, train error 77.60,  test loss 2.090888, test error 77.40
# Epoch   100, train loss 0.986862, train error 32.40,  test loss 1.373017, test error 50.05
# Epoch   200, train loss 0.770150, train error 25.25,  test loss 1.676417, test error 51.20
# Epoch   300, train loss 0.652268, train error 21.78,  test loss 2.035594, test error 53.62
# Epoch   400, train loss 0.594082, train error 20.12,  test loss 2.418027, test error 54.25
# Epoch   500, train loss 0.562701, train error 19.32,  test loss 2.804898, test error 55.95
# Epoch   600, train loss 0.507053, train error 17.05,  test loss 3.078473, test error 55.60
# Epoch   700, train loss 0.479475, train error 15.95,  test loss 3.421946, test error 57.22
# Epoch   800, train loss 0.471042, train error 16.22,  test loss 3.725969, test error 56.33
# Epoch   900, train loss 0.471477, train error 16.53,  test loss 4.043676, test error 56.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.147123, train error 79.47,  test loss 2.116170, test error 80.00
# Epoch   100, train loss 0.938254, train error 30.40,  test loss 1.443812, test error 50.15
# Epoch   200, train loss 0.650843, train error 21.45,  test loss 1.960808, test error 53.12
# Epoch   300, train loss 0.525326, train error 18.30,  test loss 2.599669, test error 55.62
# Epoch   400, train loss 0.413655, train error 13.85,  test loss 3.245879, test error 56.53
# Epoch   500, train loss 0.352326, train error 12.07,  test loss 3.904847, test error 56.33
# Epoch   600, train loss 0.384233, train error 13.38,  test loss 4.591945, test error 55.97
# Epoch   700, train loss 0.314004, train error 11.32,  test loss 5.209984, test error 56.60
# Epoch   800, train loss 0.323706, train error 12.07,  test loss 6.021234, test error 57.35
# Epoch   900, train loss 0.228414, train error 7.85,  test loss 6.482747, test error 56.83
# Training model with  45 hidden variables
# Epoch     0, train loss 2.115468, train error 79.25,  test loss 2.083220, test error 78.25
# Epoch   100, train loss 0.798781, train error 26.32,  test loss 1.547540, test error 51.62
# Epoch   200, train loss 0.465656, train error 15.25,  test loss 2.466588, test error 54.72
# Epoch   300, train loss 0.286466, train error 8.47,  test loss 3.695617, test error 57.88
# Epoch   400, train loss 0.172480, train error 4.70,  test loss 5.004657, test error 56.97
# Epoch   500, train loss 0.130259, train error 4.15,  test loss 6.498681, test error 57.15
# Epoch   600, train loss 0.067465, train error 1.38,  test loss 7.662488, test error 57.22
# Epoch   700, train loss 0.010435, train error 0.00,  test loss 8.741043, test error 57.22
# Epoch   800, train loss 0.007162, train error 0.00,  test loss 9.362434, test error 57.38
# Epoch   900, train loss 0.005458, train error 0.00,  test loss 9.840072, test error 57.50
# Training model with  50 hidden variables
# Epoch     0, train loss 2.071447, train error 76.70,  test loss 2.007952, test error 75.80
# Epoch   100, train loss 0.718989, train error 21.60,  test loss 1.548916, test error 50.10
# Epoch   200, train loss 0.368714, train error 10.70,  test loss 2.574475, test error 53.28
# Epoch   300, train loss 0.174894, train error 4.43,  test loss 4.057609, test error 54.83
# Epoch   400, train loss 0.034977, train error 0.03,  test loss 5.753543, test error 55.90
# Epoch   500, train loss 0.014353, train error 0.00,  test loss 6.786587, test error 56.15
# Epoch   600, train loss 0.008664, train error 0.00,  test loss 7.465851, test error 56.30
# Epoch   700, train loss 0.006236, train error 0.00,  test loss 7.953639, test error 56.33
# Epoch   800, train loss 0.004688, train error 0.00,  test loss 8.336949, test error 56.42
# Epoch   900, train loss 0.003784, train error 0.00,  test loss 8.664962, test error 56.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.042532, train error 76.68,  test loss 1.984478, test error 75.22
# Epoch   100, train loss 0.617209, train error 19.20,  test loss 1.707713, test error 51.83
# Epoch   200, train loss 0.188356, train error 4.38,  test loss 3.210337, test error 56.20
# Epoch   300, train loss 0.029452, train error 0.00,  test loss 4.878646, test error 55.88
# Epoch   400, train loss 0.012422, train error 0.00,  test loss 5.782802, test error 56.12
# Epoch   500, train loss 0.007418, train error 0.00,  test loss 6.355864, test error 56.20
# Epoch   600, train loss 0.005200, train error 0.00,  test loss 6.773615, test error 56.15
# Epoch   700, train loss 0.003981, train error 0.00,  test loss 7.105070, test error 56.22
# Epoch   800, train loss 0.003157, train error 0.00,  test loss 7.372896, test error 56.17
# Epoch   900, train loss 0.002617, train error 0.00,  test loss 7.602657, test error 56.12
# Training model with  60 hidden variables
# Epoch     0, train loss 2.069597, train error 76.68,  test loss 2.022623, test error 75.45
# Epoch   100, train loss 0.529440, train error 15.90,  test loss 1.741368, test error 51.25
# Epoch   200, train loss 0.135278, train error 2.32,  test loss 3.330498, test error 52.92
# Epoch   300, train loss 0.021413, train error 0.00,  test loss 4.689348, test error 53.88
# Epoch   400, train loss 0.010004, train error 0.00,  test loss 5.392972, test error 53.97
# Epoch   500, train loss 0.006267, train error 0.00,  test loss 5.848166, test error 54.05
# Epoch   600, train loss 0.004448, train error 0.00,  test loss 6.188062, test error 54.03
# Epoch   700, train loss 0.003413, train error 0.00,  test loss 6.459372, test error 54.10
# Epoch   800, train loss 0.002730, train error 0.00,  test loss 6.678174, test error 54.10
# Epoch   900, train loss 0.002264, train error 0.00,  test loss 6.865494, test error 54.03
# Training model with  70 hidden variables
# Epoch     0, train loss 2.031316, train error 74.97,  test loss 1.976723, test error 75.28
# Epoch   100, train loss 0.362024, train error 9.22,  test loss 1.969000, test error 50.67
# Epoch   200, train loss 0.032220, train error 0.00,  test loss 3.654776, test error 54.05
# Epoch   300, train loss 0.010924, train error 0.00,  test loss 4.422410, test error 53.92
# Epoch   400, train loss 0.006087, train error 0.00,  test loss 4.850937, test error 53.50
# Epoch   500, train loss 0.004120, train error 0.00,  test loss 5.154449, test error 53.80
# Epoch   600, train loss 0.003040, train error 0.00,  test loss 5.385555, test error 53.85
# Epoch   700, train loss 0.002390, train error 0.00,  test loss 5.571675, test error 53.75
# Epoch   800, train loss 0.001953, train error 0.00,  test loss 5.726115, test error 53.95
# Epoch   900, train loss 0.001641, train error 0.00,  test loss 5.857624, test error 54.10
# Training model with  80 hidden variables
# Epoch     0, train loss 2.013981, train error 75.18,  test loss 1.946305, test error 74.53
# Epoch   100, train loss 0.223165, train error 3.97,  test loss 2.081874, test error 51.22
# Epoch   200, train loss 0.020104, train error 0.00,  test loss 3.354827, test error 51.83
# Epoch   300, train loss 0.008104, train error 0.00,  test loss 3.893803, test error 51.90
# Epoch   400, train loss 0.004784, train error 0.00,  test loss 4.214132, test error 52.00
# Epoch   500, train loss 0.003309, train error 0.00,  test loss 4.446349, test error 52.12
# Epoch   600, train loss 0.002493, train error 0.00,  test loss 4.622936, test error 52.10
# Epoch   700, train loss 0.001978, train error 0.00,  test loss 4.768325, test error 52.12
# Epoch   800, train loss 0.001628, train error 0.00,  test loss 4.891221, test error 52.15
# Epoch   900, train loss 0.001376, train error 0.00,  test loss 4.997382, test error 52.17
# Training model with  90 hidden variables
# Epoch     0, train loss 2.017189, train error 75.57,  test loss 1.965508, test error 75.43
# Epoch   100, train loss 0.138956, train error 1.28,  test loss 2.186604, test error 51.50
# Epoch   200, train loss 0.014729, train error 0.00,  test loss 3.254955, test error 52.40
# Epoch   300, train loss 0.006548, train error 0.00,  test loss 3.689438, test error 52.65
# Epoch   400, train loss 0.003999, train error 0.00,  test loss 3.954920, test error 52.62
# Epoch   500, train loss 0.002811, train error 0.00,  test loss 4.145007, test error 52.60
# Epoch   600, train loss 0.002136, train error 0.00,  test loss 4.296422, test error 52.47
# Epoch   700, train loss 0.001709, train error 0.00,  test loss 4.421122, test error 52.47
# Epoch   800, train loss 0.001414, train error 0.00,  test loss 4.526466, test error 52.40
# Epoch   900, train loss 0.001201, train error 0.00,  test loss 4.616952, test error 52.40
# Training model with 100 hidden variables
# Epoch     0, train loss 1.984085, train error 73.70,  test loss 1.927200, test error 74.03
# Epoch   100, train loss 0.103686, train error 0.38,  test loss 2.151039, test error 50.70
# Epoch   200, train loss 0.012774, train error 0.00,  test loss 3.062009, test error 51.20
# Epoch   300, train loss 0.005853, train error 0.00,  test loss 3.439114, test error 51.35
# Epoch   400, train loss 0.003620, train error 0.00,  test loss 3.677852, test error 51.20
# Epoch   500, train loss 0.002553, train error 0.00,  test loss 3.851225, test error 50.97
# Epoch   600, train loss 0.001947, train error 0.00,  test loss 3.987813, test error 50.90
# Epoch   700, train loss 0.001560, train error 0.00,  test loss 4.097412, test error 50.95
# Epoch   800, train loss 0.001293, train error 0.00,  test loss 4.191453, test error 51.03
# Epoch   900, train loss 0.001099, train error 0.00,  test loss 4.271709, test error 51.05
# Training model with 120 hidden variables
# Epoch     0, train loss 1.942716, train error 70.72,  test loss 1.896104, test error 73.20
# Epoch   100, train loss 0.051723, train error 0.00,  test loss 2.193807, test error 49.90
# Epoch   200, train loss 0.009496, train error 0.00,  test loss 2.797362, test error 49.90
# Epoch   300, train loss 0.004696, train error 0.00,  test loss 3.074540, test error 50.08
# Epoch   400, train loss 0.003001, train error 0.00,  test loss 3.248920, test error 50.17
# Epoch   500, train loss 0.002163, train error 0.00,  test loss 3.378235, test error 50.42
# Epoch   600, train loss 0.001673, train error 0.00,  test loss 3.481129, test error 50.45
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.565095, test error 50.42
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.636646, test error 50.45
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.699211, test error 50.47
# Training model with 140 hidden variables
# Epoch     0, train loss 1.960072, train error 72.65,  test loss 1.890320, test error 73.45
# Epoch   100, train loss 0.038527, train error 0.00,  test loss 2.121559, test error 49.70
# Epoch   200, train loss 0.008146, train error 0.00,  test loss 2.602954, test error 49.42
# Epoch   300, train loss 0.004149, train error 0.00,  test loss 2.831101, test error 49.38
# Epoch   400, train loss 0.002690, train error 0.00,  test loss 2.978914, test error 48.97
# Epoch   500, train loss 0.001954, train error 0.00,  test loss 3.089337, test error 49.08
# Epoch   600, train loss 0.001518, train error 0.00,  test loss 3.175584, test error 49.03
# Epoch   700, train loss 0.001232, train error 0.00,  test loss 3.248309, test error 49.00
# Epoch   800, train loss 0.001031, train error 0.00,  test loss 3.310482, test error 48.95
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.364345, test error 48.92
# Training model with 160 hidden variables
# Epoch     0, train loss 1.916822, train error 70.12,  test loss 1.862132, test error 73.30
# Epoch   100, train loss 0.027231, train error 0.00,  test loss 2.134458, test error 48.95
# Epoch   200, train loss 0.006966, train error 0.00,  test loss 2.524833, test error 49.17
# Epoch   300, train loss 0.003704, train error 0.00,  test loss 2.723405, test error 48.92
# Epoch   400, train loss 0.002433, train error 0.00,  test loss 2.852118, test error 49.03
# Epoch   500, train loss 0.001787, train error 0.00,  test loss 2.951038, test error 49.03
# Epoch   600, train loss 0.001396, train error 0.00,  test loss 3.028481, test error 49.00
# Epoch   700, train loss 0.001139, train error 0.00,  test loss 3.093568, test error 49.10
# Epoch   800, train loss 0.000957, train error 0.00,  test loss 3.149157, test error 49.12
# Epoch   900, train loss 0.000821, train error 0.00,  test loss 3.197810, test error 49.10
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926302, train error 70.28,  test loss 1.854308, test error 70.88
# Epoch   100, train loss 0.023596, train error 0.00,  test loss 2.088739, test error 48.42
# Epoch   200, train loss 0.006420, train error 0.00,  test loss 2.435600, test error 48.45
# Epoch   300, train loss 0.003449, train error 0.00,  test loss 2.613554, test error 48.33
# Epoch   400, train loss 0.002290, train error 0.00,  test loss 2.732504, test error 48.50
# Epoch   500, train loss 0.001687, train error 0.00,  test loss 2.821664, test error 48.38
# Epoch   600, train loss 0.001322, train error 0.00,  test loss 2.894152, test error 48.40
# Epoch   700, train loss 0.001080, train error 0.00,  test loss 2.954336, test error 48.35
# Epoch   800, train loss 0.000908, train error 0.00,  test loss 3.005846, test error 48.33
# Epoch   900, train loss 0.000781, train error 0.00,  test loss 3.051342, test error 48.30
# Training model with 200 hidden variables
# Epoch     0, train loss 1.916798, train error 71.45,  test loss 1.842451, test error 72.90
# Epoch   100, train loss 0.021291, train error 0.00,  test loss 2.019930, test error 48.62
# Epoch   200, train loss 0.006149, train error 0.00,  test loss 2.335003, test error 48.72
# Epoch   300, train loss 0.003339, train error 0.00,  test loss 2.497634, test error 48.72
# Epoch   400, train loss 0.002225, train error 0.00,  test loss 2.605175, test error 48.75
# Epoch   500, train loss 0.001643, train error 0.00,  test loss 2.687568, test error 48.90
# Epoch   600, train loss 0.001290, train error 0.00,  test loss 2.752636, test error 48.78
# Epoch   700, train loss 0.001055, train error 0.00,  test loss 2.807384, test error 48.92
# Epoch   800, train loss 0.000889, train error 0.00,  test loss 2.854184, test error 48.83
# Epoch   900, train loss 0.000765, train error 0.00,  test loss 2.895392, test error 48.90
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886189, train error 68.20,  test loss 1.805037, test error 70.22
# Epoch   100, train loss 0.016746, train error 0.00,  test loss 1.889118, test error 46.97
# Epoch   200, train loss 0.005180, train error 0.00,  test loss 2.132006, test error 47.28
# Epoch   300, train loss 0.002896, train error 0.00,  test loss 2.260000, test error 47.17
# Epoch   400, train loss 0.001959, train error 0.00,  test loss 2.348543, test error 47.00
# Epoch   500, train loss 0.001460, train error 0.00,  test loss 2.415683, test error 46.90
# Epoch   600, train loss 0.001154, train error 0.00,  test loss 2.469375, test error 46.78
# Epoch   700, train loss 0.000948, train error 0.00,  test loss 2.514549, test error 46.90
# Epoch   800, train loss 0.000801, train error 0.00,  test loss 2.553607, test error 46.97
# Epoch   900, train loss 0.000692, train error 0.00,  test loss 2.587922, test error 47.03
# Training model with 300 hidden variables
# Epoch     0, train loss 1.892874, train error 70.05,  test loss 1.832207, test error 71.28
# Epoch   100, train loss 0.014529, train error 0.00,  test loss 1.884939, test error 47.40
# Epoch   200, train loss 0.004861, train error 0.00,  test loss 2.113576, test error 47.67
# Epoch   300, train loss 0.002752, train error 0.00,  test loss 2.231760, test error 47.65
# Epoch   400, train loss 0.001876, train error 0.00,  test loss 2.315984, test error 47.60
# Epoch   500, train loss 0.001404, train error 0.00,  test loss 2.380341, test error 47.58
# Epoch   600, train loss 0.001112, train error 0.00,  test loss 2.431698, test error 47.50
# Epoch   700, train loss 0.000916, train error 0.00,  test loss 2.474865, test error 47.53
# Epoch   800, train loss 0.000775, train error 0.00,  test loss 2.512341, test error 47.60
# Epoch   900, train loss 0.000670, train error 0.00,  test loss 2.544588, test error 47.62
# Training model with 400 hidden variables
# Epoch     0, train loss 1.859282, train error 66.50,  test loss 1.785068, test error 69.80
# Epoch   100, train loss 0.011938, train error 0.00,  test loss 1.789808, test error 45.97
# Epoch   200, train loss 0.004223, train error 0.00,  test loss 1.972428, test error 45.83
# Epoch   300, train loss 0.002446, train error 0.00,  test loss 2.073104, test error 45.85
# Epoch   400, train loss 0.001685, train error 0.00,  test loss 2.143690, test error 45.92
# Epoch   500, train loss 0.001270, train error 0.00,  test loss 2.196965, test error 46.00
# Epoch   600, train loss 0.001011, train error 0.00,  test loss 2.240674, test error 45.97
# Epoch   700, train loss 0.000835, train error 0.00,  test loss 2.277029, test error 46.08
# Epoch   800, train loss 0.000709, train error 0.00,  test loss 2.308914, test error 46.17
# Epoch   900, train loss 0.000614, train error 0.00,  test loss 2.337005, test error 46.08

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
